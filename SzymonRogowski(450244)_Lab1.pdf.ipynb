# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
print("1st Loaded")
# Out:
# 1st Loaded

# %%
img = plt.imread(r'C:\Users\szymo\PycharmProjects\SandBox\Mapa_MD_no_terrain_low_res_Gray.jpg')
print("2nd loaded")
print(type(img))
# Out:
# 2nd loaded
# <class 'numpy.ndarray'>

# %%
plt.imshow(img, cmap='gray', alpha=1)
plt.title('Map1')
plt.show()

# %%
def threshold(img, thresh=127):
    return((img > thresh) * 255).astype("uint8")

# %%
plt.imshow(threshold(img, 216), cmap='gray', alpha=0.5)
plt.title('Map2')
plt.show()
